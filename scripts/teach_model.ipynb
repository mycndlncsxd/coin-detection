# %%
from ultralytics import YOLO

# %%
test_model = YOLO('yolo26s.pt')

# %%
test_model.predict('/home/matan/Desktop/STUDYING/COURSE_Classwork/data/test', save=True)
# Out:
# image 1/7 /home/matan/Desktop/STUDYING/COURSE_Classwork/data/test/cat_and_dog.jpg: 384x640 1 cat, 2 dogs, 181.8ms
# image 2/7 /home/matan/Desktop/STUDYING/COURSE_Classwork/data/test/cats_1.jpg: 480x640 1 cat, 183.9ms
# image 3/7 /home/matan/Desktop/STUDYING/COURSE_Classwork/data/test/cats_2.jpg: 480x640 4 cats, 166.2ms
# image 4/7 /home/matan/Desktop/STUDYING/COURSE_Classwork/data/test/dogs_1.jpg: 480x640 1 bench, 3 dogs, 194.0ms
# image 5/7 /home/matan/Desktop/STUDYING/COURSE_Classwork/data/test/kitchen.jpg: 416x640 3 bottles, 1 cup, 1 bowl, 1 banana, 1 apple, 2 potted plants, 165.5ms
# image 6/7 /home/matan/Desktop/STUDYING/COURSE_Classwork/data/test/street_1.jpg: 448x640 12 persons, 1 bicycle, 5 cars, 1 handbag, 1 clock, 139.8ms
# image 7/7 /home/matan/Desktop/STUDYING/COURSE_Classwork/data/test/street_2.jpg: 640x512 6 persons, 11 cars, 1 potted plant, 130.3ms
# Speed: 2.7ms preprocess, 165.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 512)
# ...
